# %%
# %run ../../PhD-utils/AWAKE-toolbox.py

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Version 0.1
# Please report bugs to eugenio.senes@cern.ch
# Use at your own risk.

# %% [markdown]
# # Photodiode on LeCroy 18 GHz

# %%
data_path = './Photodiode-on-LeCroy-18GHz/C1stokes_avg00510.txt'

t, y, dt = load_data_LeCroy(data_path)

# %%
plt.plot(t,y)

# %% [markdown]
# # Photodiode on Tektronix

# %%
data_path = './Photodiode-on-Tek-6GHz/Tek000_ch1_20190613132737562.csv'

t, y, dt = load_data_Tektronix(data_path)

# %%
plt.plot(t,y)

# %% [markdown]
# # Streak image

# %%
from PIL import Image

# %%
ipath = '/Users/esenes/work/AWAKE-BPMs-tests/Measurements-streak-laser-independent/Streak-images/Gain40_slit20um_counts25000_1ns_continue/laserprofile001_0015.tif'

im = Image.open(ipath)
theImage = np.array(im)

# %%
plt.imshow(theImage)

# %%
plt.plot(np.sum(theImage, axis=1))

# %% [markdown]
# # Comparison

# %%
fig, ax = plt.subplots(1,2, figsize=(12,5))

ax[0].plot(t,y, label='Photodiode')
ax[0].legend()
ax[0].set_xlim(-0.5e-9, 1.2e-9)

ax[1].plot(np.sum(theImage, axis=1), label='Streak profile')
ax[1].legend()


plt.tight_layout()

# %%
fig, ax = plt.subplots(1,2, figsize=(12,5))

ax[0].plot(doFFT(t,y), label='Photodiode')
ax[0].legend()
ax[0].set_xlim(-0.5e-9, 1.2e-9)

# ax[1].plot(np.sum(theImage, axis=1), label='Streak profile')
# ax[1].legend()


plt.tight_layout()
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/tight_layout.py:181: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   warnings.warn('Tight layout not applied. '

# %%
plt.plot(doFFT(t,y)[0],dB(doFFT(t,y)[1]))
plt.xlim(0,10e9)
# Out:
# (0, 10000000000.0)
