# %% [markdown]
# # VNA measurements on a 40 mm BPM
#
# **Test notes:**
# - 40mm BPM
# - Last BPM installed in the electron beamline just before the merging with the common beamline
# - Range: 2 MHz to 20 GHz, 10k measurement points
# - Power: -5 dBm
# - System calibrated before the measurement using the two L-shape connectors for the vertical plane
# - The connectors were torque-spannered
# - The system does not look to be sensitive to the cable movement
#
# **Port map:**
#
# | VNA | BPM |
# |-----|-----|
# | 1   | H+   |
# | 2   | H-   |
# | 3   | V+   |
# | 4   | V-  |

# %%
import skrf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as pat
# %matplotlib inline

# %%
bpm = skrf.Network('./data-pictures/AWAKE_40MM_LAST_BEFORE_MERGE.S4P')

# %%
bpm.plot_s_db()

# %%
fig, ax = plt.subplots(1, dpi=150)
bpm.s11['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S11')
bpm.s22['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S22')
bpm.s33['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S33')
bpm.s44['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S44')
plt.legend()
ax.set_title('VNA analysis')
ax.grid(which='both')

# ax.set_xlim(3e9,3.1e9)

rr = pat.Rectangle((8e9, -40), 2e9,45, color='grey')
ax.add_patch(rr)
plt.savefig('Sxx-reflections.png',format='png',dpi=150)

# %%
fig, ax = plt.subplots(1, dpi=150)
bpm.s12['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S12')
bpm.s13['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S13')
bpm.s14['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S14')
plt.legend()
ax.set_title('Electrode cross-couplings')
ax.grid(which='both')

rr = pat.Rectangle((8e9, -160), 2e9,165, color='grey')
ax.add_patch(rr)
plt.savefig('Sxx-crosscouplings.png',format='png',dpi=150)

# %% [markdown]
# plot:
#     S12
#     S23
#     S34
#     S41
#
#     to find the bad electrode
#
# In sims:
#     try to offcentre a beam and simulate. The delta signal should be constant, but at some frequencies it will be not good anymore.
#     that us the f after that the system is not measuring good anymore

# %%
fig, ax = plt.subplots(1, dpi=150)
bpm.s12['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S12')
bpm.s23['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S23')
bpm.s34['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S34')
bpm.s41['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S41')
plt.legend()
ax.set_title('Electrode cross-couplings')
ax.grid(which='both')

rr = pat.Rectangle((8e9, -160), 2e9,165, color='grey')
ax.add_patch(rr)
plt.savefig('Sxx-bad-electrode.png',format='png',dpi=150)

# %%
# is the 3 the bad one ?
fig, ax = plt.subplots(1, dpi=150)
bpm.s31['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S31')
bpm.s32['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S32')
bpm.s34['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S34')
plt.legend()
ax.set_title('Electrode cross-couplings')
ax.grid(which='both')
ax.set_ylim(-180,0)

rr = pat.Rectangle((8e9, -160), 2e9,165, color='grey')
ax.add_patch(rr)
plt.savefig('Sxx-electrode3.png',format='png',dpi=150)

# %%
# is the 3 the bad one ?
fig, ax = plt.subplots(1, dpi=150)
bpm.s21['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S21')
bpm.s23['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S23')
bpm.s24['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S24')
plt.legend()
ax.set_title('Electrode cross-couplings')
ax.grid(which='both')
ax.set_ylim(-105,0)


rr = pat.Rectangle((8e9, -160), 2e9,165, color='grey')
ax.add_patch(rr)
plt.savefig('Sxx-electrode2.png',format='png',dpi=150)

# %%
# is the 3 the bad one ?
fig, ax = plt.subplots(1, dpi=150)
bpm.s41['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S41')
bpm.s42['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S42')
bpm.s43['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S43')
plt.legend()
ax.set_title('Electrode cross-couplings')
ax.grid(which='both')
ax.set_ylim(-105,0)

rr = pat.Rectangle((8e9, -160), 2e9,165, color='grey')
ax.add_patch(rr)
plt.savefig('Sxx-electrode4.png',format='png',dpi=150)

# %%
# is the 3 the bad one ?
fig, ax = plt.subplots(1, dpi=150)
bpm.s12['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S12')
bpm.s13['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S13')
bpm.s14['2000000.0-10000000000.0 Hz'].plot_s_db(ax=ax, label='S14')
plt.legend()
ax.set_title('Electrode cross-couplings')
ax.grid(which='both')
ax.set_ylim(-105,0)

rr = pat.Rectangle((8e9, -160), 2e9,165, color='grey')
ax.add_patch(rr)
plt.savefig('Sxx-electrode1.png',format='png',dpi=150)
